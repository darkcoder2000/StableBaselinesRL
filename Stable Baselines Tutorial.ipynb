# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip install tensorflow==1.15.0  --user
# !pip install tensorflow-gpu==1.15.0 --user
# !pip install stable_baselines --user
# !pip install gym --user
# !pip install box2d-py --user
# Out:
# Requirement already satisfied: tensorflow==1.15.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.0.0)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (3.19.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.15.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.21.4)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.42.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.13.3)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (0.2.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from tensorflow==1.15.0) (1.16.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from tensorflow==1.15.0) (0.37.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.1.2)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (1.15.1)
# Requirement already satisfied: gast==0.2.2 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow==1.15.0) (0.2.2)
# Requirement already satisfied: h5py in c:\users\marti\appdata\roaming\python\python37\site-packages (from keras-applications>=1.0.8->tensorflow==1.15.0) (3.6.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (58.0.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (2.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.6.0)
# Requirement already satisfied: cached-property in c:\users\marti\appdata\roaming\python\python37\site-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.0) (1.5.2)
# Requirement already satisfied: tensorflow-gpu==1.15.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (3.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.42.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.15.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from tensorflow-gpu==1.15.0) (0.37.0)
# Requirement already satisfied: gast==0.2.2 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (0.2.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.21.4)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.13.3)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (0.2.0)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from tensorflow-gpu==1.15.0) (1.16.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorflow-gpu==1.15.0) (0.8.1)
# Requirement already satisfied: h5py in c:\users\marti\appdata\roaming\python\python37\site-packages (from keras-applications>=1.0.8->tensorflow-gpu==1.15.0) (3.6.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\marti\appdata\roaming\python\python37\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (2.0.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (58.0.4)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.0) (3.6.0)
# Requirement already satisfied: cached-property in c:\users\marti\appdata\roaming\python\python37\site-packages (from h5py->keras-applications>=1.0.8->tensorflow-gpu==1.15.0) (1.5.2)
# Requirement already satisfied: stable_baselines in c:\users\marti\appdata\roaming\python\python37\site-packages (2.10.2)
# Requirement already satisfied: gym[atari,classic_control]>=0.11 in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (0.21.0)
# Requirement already satisfied: joblib in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (1.1.0)
# Requirement already satisfied: opencv-python in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (4.5.4.60)
# Requirement already satisfied: numpy in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (1.21.4)
# Requirement already satisfied: pandas in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (1.3.4)
# Requirement already satisfied: matplotlib in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (3.5.0)
# Requirement already satisfied: cloudpickle>=0.5.5 in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (2.0.0)
# Requirement already satisfied: scipy in c:\users\marti\appdata\roaming\python\python37\site-packages (from stable_baselines) (1.7.3)
# Requirement already satisfied: importlib-metadata>=4.8.1 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from gym[atari,classic_control]>=0.11->stable_baselines) (4.8.1)
# Requirement already satisfied: pyglet>=1.4.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym[atari,classic_control]>=0.11->stable_baselines) (1.5.21)
# Requirement already satisfied: ale-py~=0.7.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym[atari,classic_control]>=0.11->stable_baselines) (0.7.3)
# Requirement already satisfied: importlib-resources in c:\users\marti\appdata\roaming\python\python37\site-packages (from ale-py~=0.7.1->gym[atari,classic_control]>=0.11->stable_baselines) (5.4.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.8.1->gym[atari,classic_control]>=0.11->stable_baselines) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.8.1->gym[atari,classic_control]>=0.11->stable_baselines) (3.10.0.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\marti\appdata\roaming\python\python37\site-packages (from matplotlib->stable_baselines) (6.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from matplotlib->stable_baselines) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from matplotlib->stable_baselines) (4.28.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marti\appdata\roaming\python\python37\site-packages (from matplotlib->stable_baselines) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from matplotlib->stable_baselines) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\appdata\roaming\python\python37\site-packages (from matplotlib->stable_baselines) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from matplotlib->stable_baselines) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from matplotlib->stable_baselines) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from setuptools-scm>=4->matplotlib->stable_baselines) (58.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from setuptools-scm>=4->matplotlib->stable_baselines) (1.2.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from pandas->stable_baselines) (2021.3)
# Requirement already satisfied: gym in c:\users\marti\appdata\roaming\python\python37\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym) (1.21.4)
# Requirement already satisfied: importlib-metadata>=4.8.1 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from gym) (4.8.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.8.1->gym) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\marti\anaconda3\envs\rl_stablebaselines\lib\site-packages (from importlib-metadata>=4.8.1->gym) (3.10.0.2)
# Requirement already satisfied: box2d-py in c:\users\marti\appdata\roaming\python\python37\site-packages (2.3.8)

# %%
import gym
from stable_baselines import ACER
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.evaluation import evaluate_policy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5268/2616836226.py in <module>
#       5
#       6 import tensorflow as tf
# ----> 7 from tensorflow._api.v1.config import experiment
#       8 list_physical_devices = experiment.list_physical_devices
#       9 print(list_physical_devices)
#
# ImportError: cannot import name 'experiment' from 'tensorflow._api.v1.config' (C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\_api\v1\config\__init__.py)

# %%
environment_name = 'LunarLander-v2'

# %% [markdown]
# # 1. Test Random Environment

# %%
env = gym.make(environment_name)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-448.44080266236404
# Episode:2 Score:-376.8697082067102
# Episode:3 Score:-227.6784794972016
# Episode:4 Score:-149.78659597329522
# Episode:5 Score:-87.80742411536029
# Episode:6 Score:-218.76925073236168
# Episode:7 Score:-84.02039513896017
# Episode:8 Score:-596.3312086829578
# Episode:9 Score:-75.08455561684576
# Episode:10 Score:-297.4144676480546

# %% [markdown]
# # 2. Build and Train the Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = ACER('MlpPolicy', env, verbose = 1)
# Out:
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\acer\acer_simple.py:421: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\acer\acer_simple.py:453: The name tf.global_norm is deprecated. Please use tf.linalg.global_norm instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\acer\acer_simple.py:479: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\acer\acer_simple.py:504: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\acer\acer_simple.py:506: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
model.learn(total_timesteps=300000)
# Out:
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.69     |
# | avg_norm_grads_f    | 1.69     |
# | avg_norm_k          | 9.19     |
# | avg_norm_k_dot_g    | 2.28     |
# | entropy             | 7.3      |
# | explained_variance  | 0.671    |
# | fps                 | 0        |
# | loss                | 1.02     |
# | loss_bc             | -0       |
# | loss_f              | 0.248    |
# | loss_policy         | 0.248    |
# | loss_q              | 1.69     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 32.7     |
# | norm_grads_policy   | 11.8     |
# | norm_grads_q        | 30.5     |
# | total_timesteps     | 20       |
# ----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.895     |
# | avg_norm_g          | 1.77      |
# | avg_norm_grads_f    | 0.875     |
# | avg_norm_k          | 1         |
# | avg_norm_k_dot_g    | 1.77      |
# | entropy             | 2.19e-05  |
# | explained_variance  | -0.000402 |
# | fps                 | 256       |
# | loss                | 1.01      |
# | loss_bc             | -0        |
# | loss_f              | 1.58e-06  |
# | loss_policy         | 1.58e-06  |
# | loss_q              | 2.03      |
# | mean_episode_length | 577       |
# | mean_episode_reward | 19.3      |
# | norm_grads          | 12.8      |
# | norm_grads_policy   | 2.49e-06  |
# | norm_grads_q        | 12.8      |
# | total_timesteps     | 2020      |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0654   |
# | avg_norm_g          | 2.76     |
# | avg_norm_grads_f    | 2.14     |
# | avg_norm_k          | 59.6     |
# | avg_norm_k_dot_g    | 9.67     |
# | entropy             | 5.5      |
# | explained_variance  | 0.697    |
# | fps                 | 258      |
# | loss                | 0.691    |
# | loss_bc             | -0       |
# | loss_f              | 0.191    |
# | loss_policy         | 0.191    |
# | loss_q              | 1.11     |
# | mean_episode_length | 647      |
# | mean_episode_reward | 25.2     |
# | norm_grads          | 17.2     |
# | norm_grads_policy   | 6.99     |
# | norm_grads_q        | 15.8     |
# | total_timesteps     | 4020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.658    |
# | avg_norm_g          | 5.19     |
# | avg_norm_grads_f    | 2.48     |
# | avg_norm_k          | 5.58     |
# | avg_norm_k_dot_g    | 21.1     |
# | entropy             | 7.16     |
# | explained_variance  | 0.115    |
# | fps                 | 255      |
# | loss                | 0.468    |
# | loss_bc             | -0       |
# | loss_f              | -0.958   |
# | loss_policy         | -0.958   |
# | loss_q              | 3        |
# | mean_episode_length | 564      |
# | mean_episode_reward | -1.65    |
# | norm_grads          | 17.6     |
# | norm_grads_policy   | 5.52     |
# | norm_grads_q        | 16.7     |
# | total_timesteps     | 6020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.51     |
# | avg_norm_grads_f    | 2.51     |
# | avg_norm_k          | 2.54     |
# | avg_norm_k_dot_g    | 2.23     |
# | entropy             | 6.48     |
# | explained_variance  | -0.977   |
# | fps                 | 250      |
# | loss                | 2.06     |
# | loss_bc             | -0       |
# | loss_f              | 0.156    |
# | loss_policy         | 0.156    |
# | loss_q              | 3.94     |
# | mean_episode_length | 614      |
# | mean_episode_reward | 1.41     |
# | norm_grads          | 46.9     |
# | norm_grads_policy   | 5.43     |
# | norm_grads_q        | 46.6     |
# | total_timesteps     | 8020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.417    |
# | avg_norm_g          | 2.33     |
# | avg_norm_grads_f    | 1.94     |
# | avg_norm_k          | 2.47     |
# | avg_norm_k_dot_g    | 2.84     |
# | entropy             | 6.9      |
# | explained_variance  | 0.318    |
# | fps                 | 260      |
# | loss                | 0.392    |
# | loss_bc             | -0       |
# | loss_f              | -0.408   |
# | loss_policy         | -0.408   |
# | loss_q              | 1.74     |
# | mean_episode_length | 593      |
# | mean_episode_reward | -2.94    |
# | norm_grads          | 9.98     |
# | norm_grads_policy   | 7.33     |
# | norm_grads_q        | 6.77     |
# | total_timesteps     | 10020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 5.59     |
# | avg_norm_grads_f    | 5.59     |
# | avg_norm_k          | 18.6     |
# | avg_norm_k_dot_g    | 5.81     |
# | entropy             | 11       |
# | explained_variance  | 0.503    |
# | fps                 | 262      |
# | loss                | 4.93     |
# | loss_bc             | -0       |
# | loss_f              | 1.25     |
# | loss_policy         | 1.25     |
# | loss_q              | 7.59     |
# | mean_episode_length | 600      |
# | mean_episode_reward | -4.4     |
# | norm_grads          | 35.8     |
# | norm_grads_policy   | 15.6     |
# | norm_grads_q        | 32.2     |
# | total_timesteps     | 12020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0611   |
# | avg_norm_g          | 2.98     |
# | avg_norm_grads_f    | 2.92     |
# | avg_norm_k          | 1.99     |
# | avg_norm_k_dot_g    | 2.1      |
# | entropy             | 8.85     |
# | explained_variance  | 0.572    |
# | fps                 | 266      |
# | loss                | 1.15     |
# | loss_bc             | -0       |
# | loss_f              | 0.442    |
# | loss_policy         | 0.442    |
# | loss_q              | 1.58     |
# | mean_episode_length | 616      |
# | mean_episode_reward | -8.11    |
# | norm_grads          | 21.6     |
# | norm_grads_policy   | 7.25     |
# | norm_grads_q        | 20.4     |
# | total_timesteps     | 14020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0236   |
# | avg_norm_g          | 0.356    |
# | avg_norm_grads_f    | 0.337    |
# | avg_norm_k          | 3.53     |
# | avg_norm_k_dot_g    | 0.331    |
# | entropy             | 6.83     |
# | explained_variance  | 0.965    |
# | fps                 | 267      |
# | loss                | -0.0803  |
# | loss_bc             | -0       |
# | loss_f              | -0.0368  |
# | loss_policy         | -0.0368  |
# | loss_q              | 0.0497   |
# | mean_episode_length | 635      |
# | mean_episode_reward | 0.897    |
# | norm_grads          | 2.2      |
# | norm_grads_policy   | 1.45     |
# | norm_grads_q        | 1.65     |
# | total_timesteps     | 16020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.83     |
# | avg_norm_grads_f    | 4.83     |
# | avg_norm_k          | 2.45     |
# | avg_norm_k_dot_g    | 4.3      |
# | entropy             | 5.24     |
# | explained_variance  | 0.332    |
# | fps                 | 268      |
# | loss                | 1.29     |
# | loss_bc             | -0       |
# | loss_f              | 0.557    |
# | loss_policy         | 0.557    |
# | loss_q              | 1.58     |
# | mean_episode_length | 644      |
# | mean_episode_reward | 12.3     |
# | norm_grads          | 16.7     |
# | norm_grads_policy   | 2.41     |
# | norm_grads_q        | 16.6     |
# | total_timesteps     | 18020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.06     |
# | avg_norm_grads_f    | 2.06     |
# | avg_norm_k          | 1.96     |
# | avg_norm_k_dot_g    | 1.86     |
# | entropy             | 5.89     |
# | explained_variance  | 0.81     |
# | fps                 | 268      |
# | loss                | 0.723    |
# | loss_bc             | -0       |
# | loss_f              | 0.295    |
# | loss_policy         | 0.295    |
# | loss_q              | 0.973    |
# | mean_episode_length | 635      |
# | mean_episode_reward | 16.9     |
# | norm_grads          | 17.8     |
# | norm_grads_policy   | 6.57     |
# | norm_grads_q        | 16.6     |
# | total_timesteps     | 20020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.159    |
# | avg_norm_g          | 1.96     |
# | avg_norm_grads_f    | 1.77     |
# | avg_norm_k          | 3.29     |
# | avg_norm_k_dot_g    | 2.28     |
# | entropy             | 6.49     |
# | explained_variance  | 0.807    |
# | fps                 | 268      |
# | loss                | -0.182   |
# | loss_bc             | -0       |
# | loss_f              | -0.305   |
# | loss_policy         | -0.305   |
# | loss_q              | 0.376    |
# | mean_episode_length | 622      |
# | mean_episode_reward | 30.6     |
# | norm_grads          | 8.25     |
# | norm_grads_policy   | 2.96     |
# | norm_grads_q        | 7.7      |
# | total_timesteps     | 22020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.449    |
# | avg_norm_g          | 2.5      |
# | avg_norm_grads_f    | 2.14     |
# | avg_norm_k          | 2.04     |
# | avg_norm_k_dot_g    | 2.73     |
# | entropy             | 7.3      |
# | explained_variance  | 0.565    |
# | fps                 | 268      |
# | loss                | 0.768    |
# | loss_bc             | -0       |
# | loss_f              | -0.307   |
# | loss_policy         | -0.307   |
# | loss_q              | 2.3      |
# | mean_episode_length | 622      |
# | mean_episode_reward | 40       |
# | norm_grads          | 24.2     |
# | norm_grads_policy   | 3.37     |
# | norm_grads_q        | 24       |
# | total_timesteps     | 24020    |
# ----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.454     |
# | avg_norm_g          | 1.9       |
# | avg_norm_grads_f    | 1.19      |
# | avg_norm_k          | 2.29      |
# | avg_norm_k_dot_g    | 3.07      |
# | entropy             | 7.13      |
# | explained_variance  | -0.000235 |
# | fps                 | 270       |
# | loss                | -0.196    |
# | loss_bc             | -0        |
# | loss_f              | -0.356    |
# | loss_policy         | -0.356    |
# | loss_q              | 0.463     |
# | mean_episode_length | 604       |
# | mean_episode_reward | 36.4      |
# | norm_grads          | 3.52      |
# | norm_grads_policy   | 1.05      |
# | norm_grads_q        | 3.36      |
# | total_timesteps     | 26020     |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.81     |
# | avg_norm_g          | 13.8     |
# | avg_norm_grads_f    | 12.3     |
# | avg_norm_k          | 3.47     |
# | avg_norm_k_dot_g    | 12.3     |
# | entropy             | 8.82     |
# | explained_variance  | -0.0475  |
# | fps                 | 271      |
# | loss                | 12.2     |
# | loss_bc             | -0       |
# | loss_f              | -2.83    |
# | loss_policy         | -2.83    |
# | loss_q              | 30.2     |
# | mean_episode_length | 601      |
# | mean_episode_reward | 44.8     |
# | norm_grads          | 185      |
# | norm_grads_policy   | 30.5     |
# | norm_grads_q        | 182      |
# | total_timesteps     | 28020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.542    |
# | avg_norm_g          | 3.72     |
# | avg_norm_grads_f    | 3.26     |
# | avg_norm_k          | 1.81     |
# | avg_norm_k_dot_g    | 3.67     |
# | entropy             | 1.64     |
# | explained_variance  | 0.309    |
# | fps                 | 272      |
# | loss                | 5.34     |
# | loss_bc             | -0       |
# | loss_f              | -0.00785 |
# | loss_policy         | -0.00785 |
# | loss_q              | 10.7     |
# | mean_episode_length | 594      |
# | mean_episode_reward | 56.7     |
# | norm_grads          | 20.6     |
# | norm_grads_policy   | 1.43     |
# | norm_grads_q        | 20.5     |
# | total_timesteps     | 30020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00111  |
# | avg_norm_g          | 0.657    |
# | avg_norm_grads_f    | 0.656    |
# | avg_norm_k          | 4.02     |
# | avg_norm_k_dot_g    | 0.516    |
# | entropy             | 7.09     |
# | explained_variance  | 0.933    |
# | fps                 | 273      |
# | loss                | -0.0117  |
# | loss_bc             | -0       |
# | loss_f              | 0.000957 |
# | loss_policy         | 0.000957 |
# | loss_q              | 0.116    |
# | mean_episode_length | 575      |
# | mean_episode_reward | 62.7     |
# | norm_grads          | 5.64     |
# | norm_grads_policy   | 5.51     |
# | norm_grads_q        | 1.21     |
# | total_timesteps     | 32020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.126    |
# | avg_norm_g          | 1.05     |
# | avg_norm_grads_f    | 0.875    |
# | avg_norm_k          | 1.9      |
# | avg_norm_k_dot_g    | 1.21     |
# | entropy             | 8.72     |
# | explained_variance  | 0.923    |
# | fps                 | 272      |
# | loss                | -0.155   |
# | loss_bc             | -0       |
# | loss_f              | -0.236   |
# | loss_policy         | -0.236   |
# | loss_q              | 0.336    |
# | mean_episode_length | 578      |
# | mean_episode_reward | 74.5     |
# | norm_grads          | 10.9     |
# | norm_grads_policy   | 2.22     |
# | norm_grads_q        | 10.7     |
# | total_timesteps     | 34020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0982   |
# | avg_norm_g          | 1.79     |
# | avg_norm_grads_f    | 1.69     |
# | avg_norm_k          | 2.48     |
# | avg_norm_k_dot_g    | 2.83     |
# | entropy             | 6.53     |
# | explained_variance  | 0.876    |
# | fps                 | 271      |
# | loss                | 0.0646   |
# | loss_bc             | -0       |
# | loss_f              | -0.0165  |
# | loss_policy         | -0.0165  |
# | loss_q              | 0.293    |
# | mean_episode_length | 565      |
# | mean_episode_reward | 91.1     |
# | norm_grads          | 8.49     |
# | norm_grads_policy   | 5.93     |
# | norm_grads_q        | 6.08     |
# | total_timesteps     | 36020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 3.73     |
# | avg_norm_grads_f    | 3.73     |
# | avg_norm_k          | 3.75     |
# | avg_norm_k_dot_g    | 6.13     |
# | entropy             | 6.72     |
# | explained_variance  | 0.972    |
# | fps                 | 270      |
# | loss                | 0.369    |
# | loss_bc             | -0       |
# | loss_f              | 0.328    |
# | loss_policy         | 0.328    |
# | loss_q              | 0.216    |
# | mean_episode_length | 564      |
# | mean_episode_reward | 105      |
# | norm_grads          | 8.94     |
# | norm_grads_policy   | 1.08     |
# | norm_grads_q        | 8.87     |
# | total_timesteps     | 38020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.295    |
# | avg_norm_g          | 1.48     |
# | avg_norm_grads_f    | 1.1      |
# | avg_norm_k          | 2.98     |
# | avg_norm_k_dot_g    | 1.78     |
# | entropy             | 7.48     |
# | explained_variance  | 0.628    |
# | fps                 | 271      |
# | loss                | 0.0699   |
# | loss_bc             | -0       |
# | loss_f              | -0.268   |
# | loss_policy         | -0.268   |
# | loss_q              | 0.825    |
# | mean_episode_length | 562      |
# | mean_episode_reward | 106      |
# | norm_grads          | 16.1     |
# | norm_grads_policy   | 1.79     |
# | norm_grads_q        | 16       |
# | total_timesteps     | 40020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.952    |
# | avg_norm_grads_f    | 0.952    |
# | avg_norm_k          | 1.68     |
# | avg_norm_k_dot_g    | 0.806    |
# | entropy             | 7.84     |
# | explained_variance  | 0.975    |
# | fps                 | 271      |
# | loss                | 0.254    |
# | loss_bc             | -0       |
# | loss_f              | 0.226    |
# | loss_policy         | 0.226    |
# | loss_q              | 0.212    |
# | mean_episode_length | 551      |
# | mean_episode_reward | 107      |
# | norm_grads          | 10.6     |
# | norm_grads_policy   | 6.51     |
# | norm_grads_q        | 8.41     |
# | total_timesteps     | 42020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.382    |
# | avg_norm_g          | 1.67     |
# | avg_norm_grads_f    | 1.21     |
# | avg_norm_k          | 2        |
# | avg_norm_k_dot_g    | 1.86     |
# | entropy             | 6.49     |
# | explained_variance  | 0.346    |
# | fps                 | 268      |
# | loss                | 0.541    |
# | loss_bc             | -0       |
# | loss_f              | -0.112   |
# | loss_policy         | -0.112   |
# | loss_q              | 1.44     |
# | mean_episode_length | 582      |
# | mean_episode_reward | 97.4     |
# | norm_grads          | 9.91     |
# | norm_grads_policy   | 0.71     |
# | norm_grads_q        | 9.89     |
# | total_timesteps     | 44020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.996    |
# | avg_norm_grads_f    | 0.996    |
# | avg_norm_k          | 2.62     |
# | avg_norm_k_dot_g    | 0.974    |
# | entropy             | 8.51     |
# | explained_variance  | 0.873    |
# | fps                 | 268      |
# | loss                | 0.254    |
# | loss_bc             | -0       |
# | loss_f              | 0.143    |
# | loss_policy         | 0.143    |
# | loss_q              | 0.392    |
# | mean_episode_length | 591      |
# | mean_episode_reward | 104      |
# | norm_grads          | 6.95     |
# | norm_grads_policy   | 1.15     |
# | norm_grads_q        | 6.85     |
# | total_timesteps     | 46020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.657    |
# | avg_norm_g          | 3.28     |
# | avg_norm_grads_f    | 2.8      |
# | avg_norm_k          | 1.97     |
# | avg_norm_k_dot_g    | 3.31     |
# | entropy             | 10.7     |
# | explained_variance  | -0.0044  |
# | fps                 | 269      |
# | loss                | 0.0768   |
# | loss_bc             | -0       |
# | loss_f              | -0.764   |
# | loss_policy         | -0.764   |
# | loss_q              | 1.9      |
# | mean_episode_length | 572      |
# | mean_episode_reward | 104      |
# | norm_grads          | 33.4     |
# | norm_grads_policy   | 6.31     |
# | norm_grads_q        | 32.8     |
# | total_timesteps     | 48020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 9.53     |
# | avg_norm_grads_f    | 9.53     |
# | avg_norm_k          | 3.08     |
# | avg_norm_k_dot_g    | 19.6     |
# | entropy             | 9.93     |
# | explained_variance  | 0.504    |
# | fps                 | 269      |
# | loss                | 6.92     |
# | loss_bc             | -0       |
# | loss_f              | 2.01     |
# | loss_policy         | 2.01     |
# | loss_q              | 10       |
# | mean_episode_length | 574      |
# | mean_episode_reward | 99.6     |
# | norm_grads          | 52.5     |
# | norm_grads_policy   | 17       |
# | norm_grads_q        | 49.7     |
# | total_timesteps     | 50020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.563    |
# | avg_norm_g          | 2.47     |
# | avg_norm_grads_f    | 2.07     |
# | avg_norm_k          | 1.59     |
# | avg_norm_k_dot_g    | 2.26     |
# | entropy             | 7.3      |
# | explained_variance  | 0.821    |
# | fps                 | 270      |
# | loss                | 0.869    |
# | loss_bc             | -0       |
# | loss_f              | -0.351   |
# | loss_policy         | -0.351   |
# | loss_q              | 2.58     |
# | mean_episode_length | 582      |
# | mean_episode_reward | 113      |
# | norm_grads          | 25.2     |
# | norm_grads_policy   | 7.64     |
# | norm_grads_q        | 24.1     |
# | total_timesteps     | 52020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00714  |
# | avg_norm_g          | 1.61     |
# | avg_norm_grads_f    | 1.61     |
# | avg_norm_k          | 1.82     |
# | avg_norm_k_dot_g    | 1.53     |
# | entropy             | 10.1     |
# | explained_variance  | 0.921    |
# | fps                 | 269      |
# | loss                | 0.539    |
# | loss_bc             | -0       |
# | loss_f              | 0.291    |
# | loss_policy         | 0.291    |
# | loss_q              | 0.697    |
# | mean_episode_length | 596      |
# | mean_episode_reward | 111      |
# | norm_grads          | 15       |
# | norm_grads_policy   | 2.6      |
# | norm_grads_q        | 14.8     |
# | total_timesteps     | 54020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.169    |
# | avg_norm_g          | 1.72     |
# | avg_norm_grads_f    | 1.56     |
# | avg_norm_k          | 2.01     |
# | avg_norm_k_dot_g    | 1.8      |
# | entropy             | 6.54     |
# | explained_variance  | 0.542    |
# | fps                 | 269      |
# | loss                | 0.223    |
# | loss_bc             | -0       |
# | loss_f              | -0.0381  |
# | loss_policy         | -0.0381  |
# | loss_q              | 0.653    |
# | mean_episode_length | 595      |
# | mean_episode_reward | 98.9     |
# | norm_grads          | 5.63     |
# | norm_grads_policy   | 5.48     |
# | norm_grads_q        | 1.3      |
# | total_timesteps     | 56020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.331    |
# | avg_norm_g          | 7.74     |
# | avg_norm_grads_f    | 4.69     |
# | avg_norm_k          | 7.41     |
# | avg_norm_k_dot_g    | 43.7     |
# | entropy             | 8.61     |
# | explained_variance  | 0.165    |
# | fps                 | 270      |
# | loss                | 2.18     |
# | loss_bc             | -0       |
# | loss_f              | 0.794    |
# | loss_policy         | 0.794    |
# | loss_q              | 2.95     |
# | mean_episode_length | 580      |
# | mean_episode_reward | 103      |
# | norm_grads          | 30.5     |
# | norm_grads_policy   | 26.6     |
# | norm_grads_q        | 14.9     |
# | total_timesteps     | 58020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.197    |
# | avg_norm_g          | 5.79     |
# | avg_norm_grads_f    | 5.62     |
# | avg_norm_k          | 2.48     |
# | avg_norm_k_dot_g    | 9.26     |
# | entropy             | 8.2      |
# | explained_variance  | 0.198    |
# | fps                 | 270      |
# | loss                | -0.111   |
# | loss_bc             | -0       |
# | loss_f              | -0.553   |
# | loss_policy         | -0.553   |
# | loss_q              | 1.05     |
# | mean_episode_length | 571      |
# | mean_episode_reward | 85.3     |
# | norm_grads          | 9.8      |
# | norm_grads_policy   | 9.49     |
# | norm_grads_q        | 2.46     |
# | total_timesteps     | 60020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0277   |
# | avg_norm_g          | 0.662    |
# | avg_norm_grads_f    | 0.604    |
# | avg_norm_k          | 2.53     |
# | avg_norm_k_dot_g    | 0.814    |
# | entropy             | 8.14     |
# | explained_variance  | 0.989    |
# | fps                 | 270      |
# | loss                | -0.127   |
# | loss_bc             | -0       |
# | loss_f              | -0.1     |
# | loss_policy         | -0.1     |
# | loss_q              | 0.109    |
# | mean_episode_length | 569      |
# | mean_episode_reward | 74.2     |
# | norm_grads          | 4.43     |
# | norm_grads_policy   | 1.08     |
# | norm_grads_q        | 4.3      |
# | total_timesteps     | 62020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.49     |
# | avg_norm_g          | 5.66     |
# | avg_norm_grads_f    | 5.12     |
# | avg_norm_k          | 3.88     |
# | avg_norm_k_dot_g    | 5.2      |
# | entropy             | 8.29     |
# | explained_variance  | -1.05    |
# | fps                 | 270      |
# | loss                | 3.57     |
# | loss_bc             | -0       |
# | loss_f              | -1.19    |
# | loss_policy         | -1.19    |
# | loss_q              | 9.69     |
# | mean_episode_length | 578      |
# | mean_episode_reward | 65.8     |
# | norm_grads          | 62.6     |
# | norm_grads_policy   | 32.4     |
# | norm_grads_q        | 53.6     |
# | total_timesteps     | 64020    |
# ----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0         |
# | avg_norm_g          | 0.878     |
# | avg_norm_grads_f    | 0.878     |
# | avg_norm_k          | 1         |
# | avg_norm_k_dot_g    | 0.878     |
# | entropy             | 2.47e-09  |
# | explained_variance  | 0.451     |
# | fps                 | 270       |
# | loss                | 0.52      |
# | loss_bc             | -0        |
# | loss_f              | -8.37e-07 |
# | loss_policy         | -8.37e-07 |
# | loss_q              | 1.04      |
# | mean_episode_length | 550       |
# | mean_episode_reward | 66.1      |
# | norm_grads          | 9.02      |
# | norm_grads_policy   | 8.94e-12  |
# | norm_grads_q        | 9.02      |
# | total_timesteps     | 66020     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0         |
# | avg_norm_g          | 59.7      |
# | avg_norm_grads_f    | 59.7      |
# | avg_norm_k          | 1         |
# | avg_norm_k_dot_g    | 59.7      |
# | entropy             | 2.66e-05  |
# | explained_variance  | -0.725    |
# | fps                 | 271       |
# | loss                | 1.05e+03  |
# | loss_bc             | -0        |
# | loss_f              | -4.99e-05 |
# | loss_policy         | -4.99e-05 |
# | loss_q              | 2.09e+03  |
# | mean_episode_length | 532       |
# | mean_episode_reward | 76.8      |
# | norm_grads          | 433       |
# | norm_grads_policy   | 0.000187  |
# | norm_grads_q        | 433       |
# | total_timesteps     | 68020     |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.35     |
# | avg_norm_g          | 4.95     |
# | avg_norm_grads_f    | 4.16     |
# | avg_norm_k          | 1.72     |
# | avg_norm_k_dot_g    | 4.66     |
# | entropy             | 9.56     |
# | explained_variance  | 0.67     |
# | fps                 | 271      |
# | loss                | -0.0602  |
# | loss_bc             | -0       |
# | loss_f              | -1.16    |
# | loss_policy         | -1.16    |
# | loss_q              | 2.39     |
# | mean_episode_length | 548      |
# | mean_episode_reward | 72.5     |
# | norm_grads          | 39.8     |
# | norm_grads_policy   | 6.73     |
# | norm_grads_q        | 39.2     |
# | total_timesteps     | 70020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.82     |
# | avg_norm_grads_f    | 1.82     |
# | avg_norm_k          | 7.28     |
# | avg_norm_k_dot_g    | 1.36     |
# | entropy             | 7.41     |
# | explained_variance  | 0.829    |
# | fps                 | 271      |
# | loss                | 0.787    |
# | loss_bc             | -0       |
# | loss_f              | 0.406    |
# | loss_policy         | 0.406    |
# | loss_q              | 0.911    |
# | mean_episode_length | 521      |
# | mean_episode_reward | 71.7     |
# | norm_grads          | 25.4     |
# | norm_grads_policy   | 4.84     |
# | norm_grads_q        | 24.9     |
# | total_timesteps     | 72020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.425    |
# | avg_norm_g          | 3.24     |
# | avg_norm_grads_f    | 2.85     |
# | avg_norm_k          | 3.15     |
# | avg_norm_k_dot_g    | 2.87     |
# | entropy             | 8.18     |
# | explained_variance  | 0.417    |
# | fps                 | 272      |
# | loss                | 0.634    |
# | loss_bc             | -0       |
# | loss_f              | -0.619   |
# | loss_policy         | -0.619   |
# | loss_q              | 2.67     |
# | mean_episode_length | 498      |
# | mean_episode_reward | 53       |
# | norm_grads          | 30.8     |
# | norm_grads_policy   | 11.1     |
# | norm_grads_q        | 28.7     |
# | total_timesteps     | 74020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.29     |
# | avg_norm_g          | 11.4     |
# | avg_norm_grads_f    | 7.13     |
# | avg_norm_k          | 1.97     |
# | avg_norm_k_dot_g    | 21       |
# | entropy             | 8.74     |
# | explained_variance  | 0.918    |
# | fps                 | 273      |
# | loss                | 0.749    |
# | loss_bc             | -0       |
# | loss_f              | -2.1     |
# | loss_policy         | -2.1     |
# | loss_q              | 5.87     |
# | mean_episode_length | 471      |
# | mean_episode_reward | 49.3     |
# | norm_grads          | 74.8     |
# | norm_grads_policy   | 16.5     |
# | norm_grads_q        | 72.9     |
# | total_timesteps     | 76020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.51     |
# | avg_norm_grads_f    | 2.51     |
# | avg_norm_k          | 1.83     |
# | avg_norm_k_dot_g    | 1.79     |
# | entropy             | 10.4     |
# | explained_variance  | 0.902    |
# | fps                 | 273      |
# | loss                | 1.11     |
# | loss_bc             | -0       |
# | loss_f              | 0.632    |
# | loss_policy         | 0.632    |
# | loss_q              | 1.17     |
# | mean_episode_length | 395      |
# | mean_episode_reward | 62.1     |
# | norm_grads          | 34.7     |
# | norm_grads_policy   | 16.7     |
# | norm_grads_q        | 30.4     |
# | total_timesteps     | 78020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.756    |
# | avg_norm_g          | 3.68     |
# | avg_norm_grads_f    | 3.03     |
# | avg_norm_k          | 1.67     |
# | avg_norm_k_dot_g    | 2.29     |
# | entropy             | 7.39     |
# | explained_variance  | 0.578    |
# | fps                 | 274      |
# | loss                | 0.447    |
# | loss_bc             | -0       |
# | loss_f              | -0.599   |
# | loss_policy         | -0.599   |
# | loss_q              | 2.24     |
# | mean_episode_length | 370      |
# | mean_episode_reward | 51.8     |
# | norm_grads          | 33.5     |
# | norm_grads_policy   | 7.35     |
# | norm_grads_q        | 32.7     |
# | total_timesteps     | 80020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0859   |
# | avg_norm_g          | 0.715    |
# | avg_norm_grads_f    | 0.59     |
# | avg_norm_k          | 1.61     |
# | avg_norm_k_dot_g    | 0.776    |
# | entropy             | 14.2     |
# | explained_variance  | -0.151   |
# | fps                 | 274      |
# | loss                | -0.32    |
# | loss_bc             | -0       |
# | loss_f              | -0.231   |
# | loss_policy         | -0.231   |
# | loss_q              | 0.106    |
# | mean_episode_length | 342      |
# | mean_episode_reward | 56.4     |
# | norm_grads          | 6.6      |
# | norm_grads_policy   | 0.288    |
# | norm_grads_q        | 6.59     |
# | total_timesteps     | 82020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 8.2      |
# | avg_norm_grads_f    | 8.2      |
# | avg_norm_k          | 1.68     |
# | avg_norm_k_dot_g    | 8.6      |
# | entropy             | 13.5     |
# | explained_variance  | 0.155    |
# | fps                 | 275      |
# | loss                | 8.78     |
# | loss_bc             | -0       |
# | loss_f              | 2.59     |
# | loss_policy         | 2.59     |
# | loss_q              | 12.7     |
# | mean_episode_length | 344      |
# | mean_episode_reward | 52.9     |
# | norm_grads          | 85.8     |
# | norm_grads_policy   | 10.4     |
# | norm_grads_q        | 85.2     |
# | total_timesteps     | 84020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 10.5     |
# | avg_norm_g          | 13.9     |
# | avg_norm_grads_f    | 3.09     |
# | avg_norm_k          | 5.02     |
# | avg_norm_k_dot_g    | 26.3     |
# | entropy             | 3.29     |
# | explained_variance  | 0.489    |
# | fps                 | 275      |
# | loss                | 272      |
# | loss_bc             | -0       |
# | loss_f              | 0.111    |
# | loss_policy         | 0.111    |
# | loss_q              | 544      |
# | mean_episode_length | 361      |
# | mean_episode_reward | 42.6     |
# | norm_grads          | 202      |
# | norm_grads_policy   | 5.05     |
# | norm_grads_q        | 202      |
# | total_timesteps     | 86020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.49     |
# | avg_norm_g          | 22.7     |
# | avg_norm_grads_f    | 21.8     |
# | avg_norm_k          | 4.39     |
# | avg_norm_k_dot_g    | 23.8     |
# | entropy             | 10.1     |
# | explained_variance  | -2.66    |
# | fps                 | 276      |
# | loss                | 18.6     |
# | loss_bc             | -0       |
# | loss_f              | -4.94    |
# | loss_policy         | -4.94    |
# | loss_q              | 47.3     |
# | mean_episode_length | 368      |
# | mean_episode_reward | 59.1     |
# | norm_grads          | 174      |
# | norm_grads_policy   | 54.2     |
# | norm_grads_q        | 166      |
# | total_timesteps     | 88020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.889    |
# | avg_norm_grads_f    | 0.889    |
# | avg_norm_k          | 1.81     |
# | avg_norm_k_dot_g    | 0.972    |
# | entropy             | 8.7      |
# | explained_variance  | 0.963    |
# | fps                 | 276      |
# | loss                | 0.169    |
# | loss_bc             | -0       |
# | loss_f              | 0.198    |
# | loss_policy         | 0.198    |
# | loss_q              | 0.116    |
# | mean_episode_length | 369      |
# | mean_episode_reward | 74.8     |
# | norm_grads          | 6.11     |
# | norm_grads_policy   | 3.78     |
# | norm_grads_q        | 4.81     |
# | total_timesteps     | 90020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 6.15     |
# | avg_norm_g          | 8.24     |
# | avg_norm_grads_f    | 2.12     |
# | avg_norm_k          | 1.85     |
# | avg_norm_k_dot_g    | 8.31     |
# | entropy             | 8.2      |
# | explained_variance  | 0.229    |
# | fps                 | 277      |
# | loss                | 182      |
# | loss_bc             | -0       |
# | loss_f              | 0.14     |
# | loss_policy         | 0.14     |
# | loss_q              | 363      |
# | mean_episode_length | 385      |
# | mean_episode_reward | 80.7     |
# | norm_grads          | 39.3     |
# | norm_grads_policy   | 1.44     |
# | norm_grads_q        | 39.3     |
# | total_timesteps     | 92020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.23     |
# | avg_norm_g          | 2.27     |
# | avg_norm_grads_f    | 2.12     |
# | avg_norm_k          | 2.29     |
# | avg_norm_k_dot_g    | 2.1      |
# | entropy             | 7.83     |
# | explained_variance  | 0.615    |
# | fps                 | 277      |
# | loss                | 0.16     |
# | loss_bc             | -0       |
# | loss_f              | -0.365   |
# | loss_policy         | -0.365   |
# | loss_q              | 1.21     |
# | mean_episode_length | 400      |
# | mean_episode_reward | 89.2     |
# | norm_grads          | 5.55     |
# | norm_grads_policy   | 4.09     |
# | norm_grads_q        | 3.75     |
# | total_timesteps     | 94020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.846    |
# | avg_norm_g          | 8.37     |
# | avg_norm_grads_f    | 7.76     |
# | avg_norm_k          | 5.79     |
# | avg_norm_k_dot_g    | 5.56     |
# | entropy             | 7.71     |
# | explained_variance  | 0.0671   |
# | fps                 | 278      |
# | loss                | 3.23     |
# | loss_bc             | -0       |
# | loss_f              | -1.84    |
# | loss_policy         | -1.84    |
# | loss_q              | 10.3     |
# | mean_episode_length | 406      |
# | mean_episode_reward | 86       |
# | norm_grads          | 53       |
# | norm_grads_policy   | 38.2     |
# | norm_grads_q        | 36.8     |
# | total_timesteps     | 96020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.187    |
# | avg_norm_g          | 19.8     |
# | avg_norm_grads_f    | 19.7     |
# | avg_norm_k          | 1.5      |
# | avg_norm_k_dot_g    | 15.8     |
# | entropy             | 5.54     |
# | explained_variance  | 0.376    |
# | fps                 | 278      |
# | loss                | 28       |
# | loss_bc             | -0       |
# | loss_f              | 2.71     |
# | loss_policy         | 2.71     |
# | loss_q              | 50.7     |
# | mean_episode_length | 408      |
# | mean_episode_reward | 82       |
# | norm_grads          | 229      |
# | norm_grads_policy   | 15.9     |
# | norm_grads_q        | 228      |
# | total_timesteps     | 98020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.55     |
# | avg_norm_g          | 5.73     |
# | avg_norm_grads_f    | 4.8      |
# | avg_norm_k          | 1.72     |
# | avg_norm_k_dot_g    | 3.32     |
# | entropy             | 10.3     |
# | explained_variance  | 0.908    |
# | fps                 | 277      |
# | loss                | -0.0364  |
# | loss_bc             | -0       |
# | loss_f              | -1.16    |
# | loss_policy         | -1.16    |
# | loss_q              | 2.46     |
# | mean_episode_length | 376      |
# | mean_episode_reward | 80.7     |
# | norm_grads          | 58.3     |
# | norm_grads_policy   | 10.8     |
# | norm_grads_q        | 57.2     |
# | total_timesteps     | 100020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.942    |
# | avg_norm_grads_f    | 0.942    |
# | avg_norm_k          | 1.67     |
# | avg_norm_k_dot_g    | 0.877    |
# | entropy             | 10.2     |
# | explained_variance  | 0.975    |
# | fps                 | 275      |
# | loss                | 0.111    |
# | loss_bc             | -0       |
# | loss_f              | 0.149    |
# | loss_policy         | 0.149    |
# | loss_q              | 0.127    |
# | mean_episode_length | 386      |
# | mean_episode_reward | 89.9     |
# | norm_grads          | 6.46     |
# | norm_grads_policy   | 1.5      |
# | norm_grads_q        | 6.28     |
# | total_timesteps     | 102020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0679   |
# | avg_norm_g          | 3.12     |
# | avg_norm_grads_f    | 3.06     |
# | avg_norm_k          | 1.67     |
# | avg_norm_k_dot_g    | 2.64     |
# | entropy             | 6.87     |
# | explained_variance  | 0.971    |
# | fps                 | 274      |
# | loss                | 1.89     |
# | loss_bc             | -0       |
# | loss_f              | 0.589    |
# | loss_policy         | 0.589    |
# | loss_q              | 2.75     |
# | mean_episode_length | 378      |
# | mean_episode_reward | 75.7     |
# | norm_grads          | 29.6     |
# | norm_grads_policy   | 6.22     |
# | norm_grads_q        | 28.9     |
# | total_timesteps     | 104020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0941   |
# | avg_norm_g          | 4.94     |
# | avg_norm_grads_f    | 4.87     |
# | avg_norm_k          | 2.83     |
# | avg_norm_k_dot_g    | 7.6      |
# | entropy             | 8.94     |
# | explained_variance  | -0.489   |
# | fps                 | 272      |
# | loss                | 0.589    |
# | loss_bc             | -0       |
# | loss_f              | -0.0484  |
# | loss_policy         | -0.0484  |
# | loss_q              | 1.45     |
# | mean_episode_length | 388      |
# | mean_episode_reward | 86.5     |
# | norm_grads          | 10.4     |
# | norm_grads_policy   | 3.78     |
# | norm_grads_q        | 9.64     |
# | total_timesteps     | 106020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.03     |
# | avg_norm_g          | 10.4     |
# | avg_norm_grads_f    | 9.99     |
# | avg_norm_k          | 2.91     |
# | avg_norm_k_dot_g    | 6.31     |
# | entropy             | 7        |
# | explained_variance  | -0.0464  |
# | fps                 | 271      |
# | loss                | 1.27     |
# | loss_bc             | -0       |
# | loss_f              | -1.75    |
# | loss_policy         | -1.75    |
# | loss_q              | 6.19     |
# | mean_episode_length | 402      |
# | mean_episode_reward | 77.4     |
# | norm_grads          | 34.2     |
# | norm_grads_policy   | 29.2     |
# | norm_grads_q        | 17.8     |
# | total_timesteps     | 108020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.88     |
# | avg_norm_grads_f    | 4.88     |
# | avg_norm_k          | 1.92     |
# | avg_norm_k_dot_g    | 5.49     |
# | entropy             | 9.81     |
# | explained_variance  | 0.833    |
# | fps                 | 269      |
# | loss                | 2.42     |
# | loss_bc             | -0       |
# | loss_f              | 1.37     |
# | loss_policy         | 1.37     |
# | loss_q              | 2.29     |
# | mean_episode_length | 423      |
# | mean_episode_reward | 76.2     |
# | norm_grads          | 46.9     |
# | norm_grads_policy   | 9.13     |
# | norm_grads_q        | 46       |
# | total_timesteps     | 110020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.5      |
# | avg_norm_grads_f    | 2.5      |
# | avg_norm_k          | 1.79     |
# | avg_norm_k_dot_g    | 1.86     |
# | entropy             | 12.4     |
# | explained_variance  | 0.941    |
# | fps                 | 268      |
# | loss                | 0.974    |
# | loss_bc             | -0       |
# | loss_f              | 0.59     |
# | loss_policy         | 0.59     |
# | loss_q              | 1.02     |
# | mean_episode_length | 419      |
# | mean_episode_reward | 66.6     |
# | norm_grads          | 27.3     |
# | norm_grads_policy   | 2.16     |
# | norm_grads_q        | 27.2     |
# | total_timesteps     | 112020   |
# ----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.0234    |
# | avg_norm_g          | 0.727     |
# | avg_norm_grads_f    | 0.704     |
# | avg_norm_k          | 1         |
# | avg_norm_k_dot_g    | 0.727     |
# | entropy             | 1.69e-09  |
# | explained_variance  | 0.463     |
# | fps                 | 267       |
# | loss                | 0.578     |
# | loss_bc             | -0        |
# | loss_f              | -9.96e-08 |
# | loss_policy         | -9.96e-08 |
# | loss_q              | 1.16      |
# | mean_episode_length | 409       |
# | mean_episode_reward | 69.8      |
# | norm_grads          | 2.14      |
# | norm_grads_policy   | 1.21e-12  |
# | norm_grads_q        | 2.14      |
# | total_timesteps     | 114020    |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.65     |
# | avg_norm_g          | 5.29     |
# | avg_norm_grads_f    | 3.07     |
# | avg_norm_k          | 7.73     |
# | avg_norm_k_dot_g    | 7.24     |
# | entropy             | 8.38     |
# | explained_variance  | 0.886    |
# | fps                 | 266      |
# | loss                | 6.25     |
# | loss_bc             | -0       |
# | loss_f              | -1.04    |
# | loss_policy         | -1.04    |
# | loss_q              | 14.8     |
# | mean_episode_length | 428      |
# | mean_episode_reward | 74.2     |
# | norm_grads          | 94.2     |
# | norm_grads_policy   | 5.59     |
# | norm_grads_q        | 94       |
# | total_timesteps     | 116020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.682    |
# | avg_norm_g          | 3.11     |
# | avg_norm_grads_f    | 2.67     |
# | avg_norm_k          | 1.72     |
# | avg_norm_k_dot_g    | 2.82     |
# | entropy             | 10.7     |
# | explained_variance  | 0.828    |
# | fps                 | 266      |
# | loss                | 0.0384   |
# | loss_bc             | -0       |
# | loss_f              | -0.657   |
# | loss_policy         | -0.657   |
# | loss_q              | 1.61     |
# | mean_episode_length | 407      |
# | mean_episode_reward | 73.8     |
# | norm_grads          | 32.5     |
# | norm_grads_policy   | 9.54     |
# | norm_grads_q        | 31.1     |
# | total_timesteps     | 118020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.018    |
# | avg_norm_g          | 0.7      |
# | avg_norm_grads_f    | 0.679    |
# | avg_norm_k          | 1.89     |
# | avg_norm_k_dot_g    | 0.749    |
# | entropy             | 11.8     |
# | explained_variance  | 0.983    |
# | fps                 | 266      |
# | loss                | 0.0131   |
# | loss_bc             | -0       |
# | loss_f              | 0.0763   |
# | loss_policy         | 0.0763   |
# | loss_q              | 0.11     |
# | mean_episode_length | 435      |
# | mean_episode_reward | 76.1     |
# | norm_grads          | 7.97     |
# | norm_grads_policy   | 0.95     |
# | norm_grads_q        | 7.91     |
# | total_timesteps     | 120020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.65     |
# | avg_norm_grads_f    | 1.65     |
# | avg_norm_k          | 2.33     |
# | avg_norm_k_dot_g    | 1.46     |
# | entropy             | 10.9     |
# | explained_variance  | 0.947    |
# | fps                 | 265      |
# | loss                | 0.591    |
# | loss_bc             | -0       |
# | loss_f              | 0.317    |
# | loss_policy         | 0.317    |
# | loss_q              | 0.766    |
# | mean_episode_length | 454      |
# | mean_episode_reward | 82.1     |
# | norm_grads          | 16       |
# | norm_grads_policy   | 2.65     |
# | norm_grads_q        | 15.7     |
# | total_timesteps     | 122020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.424    |
# | avg_norm_g          | 2.41     |
# | avg_norm_grads_f    | 2.18     |
# | avg_norm_k          | 1.9      |
# | avg_norm_k_dot_g    | 1.86     |
# | entropy             | 9.43     |
# | explained_variance  | 0.415    |
# | fps                 | 265      |
# | loss                | -0.0985  |
# | loss_bc             | -0       |
# | loss_f              | -0.471   |
# | loss_policy         | -0.471   |
# | loss_q              | 0.934    |
# | mean_episode_length | 424      |
# | mean_episode_reward | 94       |
# | norm_grads          | 16.7     |
# | norm_grads_policy   | 12.8     |
# | norm_grads_q        | 10.7     |
# | total_timesteps     | 124020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.101    |
# | avg_norm_g          | 3.94     |
# | avg_norm_grads_f    | 3.9      |
# | avg_norm_k          | 2.2      |
# | avg_norm_k_dot_g    | 3.52     |
# | entropy             | 7.55     |
# | explained_variance  | 0.131    |
# | fps                 | 265      |
# | loss                | 1.77     |
# | loss_bc             | -0       |
# | loss_f              | 0.458    |
# | loss_policy         | 0.458    |
# | loss_q              | 2.78     |
# | mean_episode_length | 412      |
# | mean_episode_reward | 108      |
# | norm_grads          | 32.3     |
# | norm_grads_policy   | 3        |
# | norm_grads_q        | 32.2     |
# | total_timesteps     | 126020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.199    |
# | avg_norm_g          | 3.75     |
# | avg_norm_grads_f    | 3.6      |
# | avg_norm_k          | 1.83     |
# | avg_norm_k_dot_g    | 2.71     |
# | entropy             | 9.88     |
# | explained_variance  | -0.572   |
# | fps                 | 265      |
# | loss                | 1.02     |
# | loss_bc             | -0       |
# | loss_f              | 0.181    |
# | loss_policy         | 0.181    |
# | loss_q              | 1.88     |
# | mean_episode_length | 420      |
# | mean_episode_reward | 116      |
# | norm_grads          | 6.05     |
# | norm_grads_policy   | 3.73     |
# | norm_grads_q        | 4.76     |
# | total_timesteps     | 128020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.431    |
# | avg_norm_g          | 3.91     |
# ...
# | avg_norm_k_dot_g    | 12.3     |
# | entropy             | 9.73     |
# | explained_variance  | -3.99    |
# | fps                 | 270      |
# | loss                | 20.6     |
# | loss_bc             | -0       |
# | loss_f              | -2.38    |
# | loss_policy         | -2.38    |
# | loss_q              | 46.1     |
# | mean_episode_length | 393      |
# | mean_episode_reward | 22       |
# | norm_grads          | 250      |
# | norm_grads_policy   | 34       |
# | norm_grads_q        | 248      |
# | total_timesteps     | 256020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0196   |
# | avg_norm_g          | 2.7      |
# | avg_norm_grads_f    | 2.68     |
# | avg_norm_k          | 1.93     |
# | avg_norm_k_dot_g    | 2.64     |
# | entropy             | 10.4     |
# | explained_variance  | -1.69    |
# | fps                 | 270      |
# | loss                | 1.2      |
# | loss_bc             | -0       |
# | loss_f              | 0.506    |
# | loss_policy         | 0.506    |
# | loss_q              | 1.6      |
# | mean_episode_length | 300      |
# | mean_episode_reward | 16.2     |
# | norm_grads          | 26       |
# | norm_grads_policy   | 6.64     |
# | norm_grads_q        | 25.2     |
# | total_timesteps     | 258020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.000381 |
# | avg_norm_g          | 2.26     |
# | avg_norm_grads_f    | 2.26     |
# | avg_norm_k          | 1.91     |
# | avg_norm_k_dot_g    | 2.11     |
# | entropy             | 10.6     |
# | explained_variance  | -1.1     |
# | fps                 | 270      |
# | loss                | 1.1      |
# | loss_bc             | -0       |
# | loss_f              | 0.457    |
# | loss_policy         | 0.457    |
# | loss_q              | 1.5      |
# | mean_episode_length | 331      |
# | mean_episode_reward | 8.37     |
# | norm_grads          | 19.8     |
# | norm_grads_policy   | 7.6      |
# | norm_grads_q        | 18.3     |
# | total_timesteps     | 260020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.056    |
# | avg_norm_g          | 0.673    |
# | avg_norm_grads_f    | 0.62     |
# | avg_norm_k          | 2.18     |
# | avg_norm_k_dot_g    | 0.75     |
# | entropy             | 8        |
# | explained_variance  | 0.918    |
# | fps                 | 271      |
# | loss                | -0.109   |
# | loss_bc             | -0       |
# | loss_f              | -0.0731  |
# | loss_policy         | -0.0731  |
# | loss_q              | 0.0889   |
# | mean_episode_length | 338      |
# | mean_episode_reward | -22.3    |
# | norm_grads          | 0.782    |
# | norm_grads_policy   | 0.471    |
# | norm_grads_q        | 0.624    |
# | total_timesteps     | 262020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.69     |
# | avg_norm_grads_f    | 4.69     |
# | avg_norm_k          | 1.69     |
# | avg_norm_k_dot_g    | 4.61     |
# | entropy             | 13.2     |
# | explained_variance  | 0.973    |
# | fps                 | 271      |
# | loss                | 2.17     |
# | loss_bc             | -0       |
# | loss_f              | 1.28     |
# | loss_policy         | 1.28     |
# | loss_q              | 2.04     |
# | mean_episode_length | 334      |
# | mean_episode_reward | -26.4    |
# | norm_grads          | 51.7     |
# | norm_grads_policy   | 3.73     |
# | norm_grads_q        | 51.6     |
# | total_timesteps     | 264020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.94     |
# | avg_norm_g          | 7.71     |
# | avg_norm_grads_f    | 6.47     |
# | avg_norm_k          | 1.9      |
# | avg_norm_k_dot_g    | 8.12     |
# | entropy             | 9.13     |
# | explained_variance  | -1.33    |
# | fps                 | 271      |
# | loss                | 5.71     |
# | loss_bc             | -0       |
# | loss_f              | -1.74    |
# | loss_policy         | -1.74    |
# | loss_q              | 15.1     |
# | mean_episode_length | 320      |
# | mean_episode_reward | -18.5    |
# | norm_grads          | 89.1     |
# | norm_grads_policy   | 22.2     |
# | norm_grads_q        | 86.3     |
# | total_timesteps     | 266020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 18.9     |
# | avg_norm_grads_f    | 18.9     |
# | avg_norm_k          | 2.02     |
# | avg_norm_k_dot_g    | 19.1     |
# | entropy             | 7.43     |
# | explained_variance  | -0.0743  |
# | fps                 | 271      |
# | loss                | 10.2     |
# | loss_bc             | -0       |
# | loss_f              | 3.61     |
# | loss_policy         | 3.61     |
# | loss_q              | 13.2     |
# | mean_episode_length | 291      |
# | mean_episode_reward | -14.8    |
# | norm_grads          | 112      |
# | norm_grads_policy   | 24.3     |
# | norm_grads_q        | 110      |
# | total_timesteps     | 268020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.428    |
# | avg_norm_g          | 2.83     |
# | avg_norm_grads_f    | 2.55     |
# | avg_norm_k          | 2.04     |
# | avg_norm_k_dot_g    | 2.71     |
# | entropy             | 4.5      |
# | explained_variance  | 0.0265   |
# | fps                 | 271      |
# | loss                | 2.4      |
# | loss_bc             | -0       |
# | loss_f              | -0.143   |
# | loss_policy         | -0.143   |
# | loss_q              | 5.17     |
# | mean_episode_length | 314      |
# | mean_episode_reward | -11      |
# | norm_grads          | 58.5     |
# | norm_grads_policy   | 8.49     |
# | norm_grads_q        | 57.9     |
# | total_timesteps     | 270020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 3.79     |
# | avg_norm_grads_f    | 3.79     |
# | avg_norm_k          | 1.69     |
# | avg_norm_k_dot_g    | 3.61     |
# | entropy             | 12.7     |
# | explained_variance  | 0.861    |
# | fps                 | 272      |
# | loss                | 1.77     |
# | loss_bc             | -0       |
# | loss_f              | 1.03     |
# | loss_policy         | 1.03     |
# | loss_q              | 1.74     |
# | mean_episode_length | 291      |
# | mean_episode_reward | 7.52     |
# | norm_grads          | 36.2     |
# | norm_grads_policy   | 9.15     |
# | norm_grads_q        | 35       |
# | total_timesteps     | 272020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.91     |
# | avg_norm_g          | 5.11     |
# | avg_norm_grads_f    | 3.68     |
# | avg_norm_k          | 1.32     |
# | avg_norm_k_dot_g    | 4.61     |
# | entropy             | 12.5     |
# | explained_variance  | -0.278   |
# | fps                 | 272      |
# | loss                | 1.43     |
# | loss_bc             | -0       |
# | loss_f              | -1.26    |
# | loss_policy         | -1.26    |
# | loss_q              | 5.64     |
# | mean_episode_length | 266      |
# | mean_episode_reward | 12.2     |
# | norm_grads          | 20.9     |
# | norm_grads_policy   | 7.74     |
# | norm_grads_q        | 19.5     |
# | total_timesteps     | 274020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.6      |
# | avg_norm_g          | 11.5     |
# | avg_norm_grads_f    | 9.38     |
# | avg_norm_k          | 1.65     |
# | avg_norm_k_dot_g    | 11.1     |
# | entropy             | 7.14     |
# | explained_variance  | 0.509    |
# | fps                 | 272      |
# | loss                | 5.74     |
# | loss_bc             | -0       |
# | loss_f              | -2.4     |
# | loss_policy         | -2.4     |
# | loss_q              | 16.4     |
# | mean_episode_length | 298      |
# | mean_episode_reward | 23.8     |
# | norm_grads          | 92.8     |
# | norm_grads_policy   | 16.7     |
# | norm_grads_q        | 91.3     |
# | total_timesteps     | 276020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.662    |
# | avg_norm_g          | 2.22     |
# | avg_norm_grads_f    | 1.69     |
# | avg_norm_k          | 1.42     |
# | avg_norm_k_dot_g    | 2.29     |
# | entropy             | 14.3     |
# | explained_variance  | -0.111   |
# | fps                 | 272      |
# | loss                | -0.488   |
# | loss_bc             | -0       |
# | loss_f              | -0.704   |
# | loss_policy         | -0.704   |
# | loss_q              | 0.717    |
# | mean_episode_length | 292      |
# | mean_episode_reward | 20.2     |
# | norm_grads          | 21.8     |
# | norm_grads_policy   | 9.23     |
# | norm_grads_q        | 19.8     |
# | total_timesteps     | 278020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.53     |
# | avg_norm_g          | 5.56     |
# | avg_norm_grads_f    | 4.58     |
# | avg_norm_k          | 1.78     |
# | avg_norm_k_dot_g    | 5.66     |
# | entropy             | 10.4     |
# | explained_variance  | -2.76    |
# | fps                 | 273      |
# | loss                | 2.59     |
# | loss_bc             | -0       |
# | loss_f              | -1.4     |
# | loss_policy         | -1.4     |
# | loss_q              | 8.17     |
# | mean_episode_length | 322      |
# | mean_episode_reward | 26.4     |
# | norm_grads          | 78.5     |
# | norm_grads_policy   | 14       |
# | norm_grads_q        | 77.2     |
# | total_timesteps     | 280020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.89     |
# | avg_norm_g          | 4.2      |
# | avg_norm_grads_f    | 3.67     |
# | avg_norm_k          | 1.69     |
# | avg_norm_k_dot_g    | 3.97     |
# | entropy             | 11.9     |
# | explained_variance  | 0.814    |
# | fps                 | 273      |
# | loss                | 0.223    |
# | loss_bc             | -0       |
# | loss_f              | -0.52    |
# | loss_policy         | -0.52    |
# | loss_q              | 1.73     |
# | mean_episode_length | 321      |
# | mean_episode_reward | 26       |
# | norm_grads          | 41.4     |
# | norm_grads_policy   | 3.36     |
# | norm_grads_q        | 41.3     |
# | total_timesteps     | 282020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 7.49     |
# | avg_norm_grads_f    | 7.49     |
# | avg_norm_k          | 1.71     |
# | avg_norm_k_dot_g    | 7.15     |
# | entropy             | 14.7     |
# | explained_variance  | -0.25    |
# | fps                 | 273      |
# | loss                | 8.34     |
# | loss_bc             | -0       |
# | loss_f              | 2.64     |
# | loss_policy         | 2.64     |
# | loss_q              | 11.7     |
# | mean_episode_length | 317      |
# | mean_episode_reward | 29.1     |
# | norm_grads          | 71.5     |
# | norm_grads_policy   | 58.7     |
# | norm_grads_q        | 40.8     |
# | total_timesteps     | 284020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.604    |
# | avg_norm_g          | 3.8      |
# | avg_norm_grads_f    | 3.45     |
# | avg_norm_k          | 1.79     |
# | avg_norm_k_dot_g    | 3.71     |
# | entropy             | 12.4     |
# | explained_variance  | 0.759    |
# | fps                 | 273      |
# | loss                | 0.862    |
# | loss_bc             | -0       |
# | loss_f              | -0.108   |
# | loss_policy         | -0.108   |
# | loss_q              | 2.19     |
# | mean_episode_length | 342      |
# | mean_episode_reward | 36.4     |
# | norm_grads          | 18.5     |
# | norm_grads_policy   | 11.4     |
# | norm_grads_q        | 14.5     |
# | total_timesteps     | 286020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.678    |
# | avg_norm_g          | 2.86     |
# | avg_norm_grads_f    | 2.44     |
# | avg_norm_k          | 1.58     |
# | avg_norm_k_dot_g    | 2.86     |
# | entropy             | 5.53     |
# | explained_variance  | 0.995    |
# | fps                 | 273      |
# | loss                | -0.048   |
# | loss_bc             | -0       |
# | loss_f              | -0.382   |
# | loss_policy         | -0.382   |
# | loss_q              | 0.779    |
# | mean_episode_length | 323      |
# | mean_episode_reward | 27.2     |
# | norm_grads          | 20.5     |
# | norm_grads_policy   | 2.5      |
# | norm_grads_q        | 20.3     |
# | total_timesteps     | 288020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.507    |
# | avg_norm_g          | 2.36     |
# | avg_norm_grads_f    | 2.01     |
# | avg_norm_k          | 1.57     |
# | avg_norm_k_dot_g    | 2.36     |
# | entropy             | 6.41     |
# | explained_variance  | 0.992    |
# | fps                 | 273      |
# | loss                | 0.455    |
# | loss_bc             | -0       |
# | loss_f              | -0.334   |
# | loss_policy         | -0.334   |
# | loss_q              | 1.71     |
# | mean_episode_length | 331      |
# | mean_episode_reward | 37.2     |
# | norm_grads          | 36       |
# | norm_grads_policy   | 4.3      |
# | norm_grads_q        | 35.8     |
# | total_timesteps     | 290020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.3      |
# | avg_norm_g          | 4.91     |
# | avg_norm_grads_f    | 4.11     |
# | avg_norm_k          | 1.73     |
# | avg_norm_k_dot_g    | 4.97     |
# | entropy             | 13.7     |
# | explained_variance  | 0.178    |
# | fps                 | 273      |
# | loss                | 2.91     |
# | loss_bc             | -0       |
# | loss_f              | -1.06    |
# | loss_policy         | -1.06    |
# | loss_q              | 8.22     |
# | mean_episode_length | 337      |
# | mean_episode_reward | 51.1     |
# | norm_grads          | 101      |
# | norm_grads_policy   | 6.66     |
# | norm_grads_q        | 100      |
# | total_timesteps     | 292020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 3.18     |
# | avg_norm_grads_f    | 3.18     |
# | avg_norm_k          | 1.87     |
# | avg_norm_k_dot_g    | 3.24     |
# | entropy             | 7.22     |
# | explained_variance  | -0.567   |
# | fps                 | 273      |
# | loss                | 1.3      |
# | loss_bc             | -0       |
# | loss_f              | 0.47     |
# | loss_policy         | 0.47     |
# | loss_q              | 1.81     |
# | mean_episode_length | 335      |
# | mean_episode_reward | 37.8     |
# | norm_grads          | 27.4     |
# | norm_grads_policy   | 5.89     |
# | norm_grads_q        | 26.7     |
# | total_timesteps     | 294020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 6.97     |
# | avg_norm_g          | 7.96     |
# | avg_norm_grads_f    | 0.995    |
# | avg_norm_k          | 1        |
# | avg_norm_k_dot_g    | 7.96     |
# | entropy             | 1.44e-10 |
# | explained_variance  | -3.38    |
# | fps                 | 273      |
# | loss                | 21.3     |
# | loss_bc             | -0       |
# | loss_f              | 7.03e-06 |
# | loss_policy         | 7.03e-06 |
# | loss_q              | 42.7     |
# | mean_episode_length | 343      |
# | mean_episode_reward | 27.5     |
# | norm_grads          | 161      |
# | norm_grads_policy   | 1.23e-12 |
# | norm_grads_q        | 161      |
# | total_timesteps     | 296020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 19.8     |
# | avg_norm_g          | 60.2     |
# | avg_norm_grads_f    | 49.1     |
# | avg_norm_k          | 1.74     |
# | avg_norm_k_dot_g    | 60.7     |
# | entropy             | 7.43     |
# | explained_variance  | -0.358   |
# | fps                 | 273      |
# | loss                | 6.81     |
# | loss_bc             | -0       |
# | loss_f              | -4.23    |
# | loss_policy         | -4.23    |
# | loss_q              | 22.2     |
# | mean_episode_length | 317      |
# | mean_episode_reward | 12.9     |
# | norm_grads          | 201      |
# | norm_grads_policy   | 18.6     |
# | norm_grads_q        | 200      |
# | total_timesteps     | 298020   |
# ----------------------------------

# %% [markdown]
# # 3. Save and Test the Model

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()

# %%
model.save("ACER_model")

# %%
del model

# %%
model = ACER.load("ACER_model", env=env)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\marti\AppData\Local\Temp/ipykernel_20808/1607814126.py", line 5, in <module>
#     env.render()
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\vec_env\dummy_vec_env.py", line 85, in render
#     return self.envs[0].render(mode=mode)
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\core.py", line 295, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\envs\box2d\lunar_lander.py", line 442, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\envs\classic_control\rendering.py", line 145, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\pyglet\window\win32\__init__.py", line 375, in flip
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\marti\AppData\Local\Temp/ipykernel_20808/1607814126.py", line 5, in <module>
#     env.render()
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\vec_env\dummy_vec_env.py", line 85, in render
#     return self.envs[0].render(mode=mode)
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\core.py", line 295, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\envs\box2d\lunar_lander.py", line 442, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\envs\classic_control\rendering.py", line 145, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\pyglet\window\win32\__init__.py", line 375, in flip
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\marti\AppData\Local\Temp/ipykernel_20808/1607814126.py", line 5, in <module>
#     env.render()
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\stable_baselines\common\vec_env\dummy_vec_env.py", line 85, in render
#     return self.envs[0].render(mode=mode)
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\core.py", line 295, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\envs\box2d\lunar_lander.py", line 442, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\gym\envs\classic_control\rendering.py", line 145, in render
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\pyglet\window\win32\__init__.py", line 375, in flip
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#   File "C:\Users\marti\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py", line 44, in _load
#   File "C:\Users\marti\anaconda3\envs\RL_StableBaselines\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.keras'

# %%
env.close()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 17
